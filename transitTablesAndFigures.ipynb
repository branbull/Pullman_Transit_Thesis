# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import os
import statistics

plt.rcParams.update({'font.size': 20})
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

pd.set_option('display.max_rows', 200)
pd.set_option('display.min_rows', 200)

#os.chdir(r'C:/Users/brand/OneDrive - Washington State University (email.wsu.edu)/Brandon')
os.chdir("C:/Users/jake.wagner/OneDrive - Washington State University (email.wsu.edu)/WSU_Econ/Research/TRG/PacTrans/Brandon TRG")

# %%
#import transit dataframe
df = pd.read_csv('transitCleaned.csv',parse_dates=['Date'])
os.chdir("C:/Users/jake.wagner/OneDrive - Washington State University (email.wsu.edu)/WSU_Econ/Research/TRG/PacTrans/Brandon TRG/Text/figures")
df['Ridership'] = df['Ons']+df['Offs']
df
# Out:
# C:\Users\jake.wagner\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        VehicleName                  RouteName  \
# 0              314                       Loop
# 1              314                       Loop
# 2              314                       Loop
# 3              314                       Loop
# 4              314                       Loop
# 5              314                       Loop
# 6              314                       Loop
# 7              314                       Loop
# 8              314                       Loop
# 9              314                       Loop
# 10             314                       Loop
# 11             314                       Loop
# 12             314                       Loop
# 13             314                       Loop
# ...

# %%
#General descriptive stats of whole dataset
df.describe(include='all')
# Out:
#         VehicleName RouteName         stop_name                 Date  \
# count      774704.0    774704            774704               774704
# unique         49.0        40               223                  624
# top           306.0      Loop  Transfer Station  2019-05-01 00:00:00
# freq        36202.0     87380             22297                 5526
# first           NaN       NaN               NaN  2019-01-02 00:00:00
# last            NaN       NaN               NaN  2020-12-31 00:00:00
# mean            NaN       NaN               NaN                  NaN
# std             NaN       NaN               NaN                  NaN
# min             NaN       NaN               NaN                  NaN
# 25%             NaN       NaN               NaN                  NaN
# 50%             NaN       NaN               NaN                  NaN
# 75%             NaN       NaN               NaN                  NaN
# max             NaN       NaN               NaN                  NaN
#
# ...

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'}).reset_index().Date.dt.month_name()[:12], df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})[:12]['Ons'], label = "2019")
ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'}).reset_index().Date.dt.month_name()[12:], df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})[12:]['Ons'], label = "2020")
#ax1.plot(df.groupby(['Year','Month']).sum().loc[2020,'Ons'].reset_index()['Month'], df.groupby(['Year','Month']).sum().loc[2020,'Ons'], label = '2020')
#ax1.set_title('Total Monthly Boardings, 2019-2021')
ax1.set_xlabel('Month')
ax1.set_ylabel('Boardings')
ax1.set_ylim(ymin=0)

plt.xticks(rotation=-45, ha='left')
plt.legend()

plt.savefig('monthlyBoardings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'}).reset_index().Date.dt.month_name()[:12], df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})[:12]['Offs'], label = "2019")
ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'}).reset_index().Date.dt.month_name()[12:], df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})[12:]['Offs'], label = "2020")
#ax1.plot(df.groupby(['Year','Month']).sum().loc[2020,'Ons'].reset_index()['Month'], df.groupby(['Year','Month']).sum().loc[2020,'Ons'], label = '2020')
#ax1.set_title('Total Monthly Boardings, 2019-2021')
ax1.set_xlabel('Month')
ax1.set_ylabel('Alightings')
ax1.set_ylim(ymin=0)

plt.xticks(rotation=-45, ha='left')
plt.legend()

plt.savefig('monthlyAlightings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'}).reset_index().Date.dt.month_name()[:12], df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})[:12]['Ridership'], label = "2019")
ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'}).reset_index().Date.dt.month_name()[12:], df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})[12:]['Ridership'], label = "2020")
#ax1.plot(df.groupby(['Year','Month']).sum().loc[2020,'Ons'].reset_index()['Month'], df.groupby(['Year','Month']).sum().loc[2020,'Ons'], label = '2020')
#ax1.set_title('Total Monthly Boardings, 2019-2021')
ax1.set_xlabel('Month')
ax1.set_ylabel('Ridership')
ax1.set_ylim(ymin=0)

plt.xticks(rotation=-45, ha='left')
plt.legend()

plt.savefig('monthlyRidership.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Week':'mean'}).reset_index()['Week'][1:52], df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})[1:52]['Ons'], label = "2019")
ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Week':'mean'}).reset_index()['Week'][52:-1], df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})[52:-1]['Ons'], label = "2020")
#ax1.set_title('Total Weekly Boardings, 2019-2021')
ax1.set_xlabel('Week')
ax1.set_ylabel('Boardings')
ax1.set_ylim(ymin=0)


ax1.vlines(x=11,ymin=0,ymax=max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons']),color='r',ls='--')

plt.legend()

plt.savefig('weeklyBoardings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Week':'mean'}).reset_index()['Week'][1:52], df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})[1:52]['Offs'], label = "2019")
ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Week':'mean'}).reset_index()['Week'][52:-1], df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})[52:-1]['Offs'], label = "2020")
#ax1.set_title('Total Weekly Boardings, 2019-2021')
ax1.set_xlabel('Week')
ax1.set_ylabel('Alightings')
ax1.set_ylim(ymin=0)


ax1.vlines(x=11,ymin=0,ymax=max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons']),color='r',ls='--')

plt.legend()

plt.savefig('weeklyAlightings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Week':'mean','Ridership':'sum'}).reset_index()['Week'][1:52], df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})[1:52]['Ridership'], label = "2019")
ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Week':'mean','Ridership':'sum'}).reset_index()['Week'][52:-1], df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})[52:-1]['Ridership'], label = "2020")
#ax1.set_title('Total Weekly Boardings, 2019-2021')
ax1.set_xlabel('Week')
ax1.set_ylabel('Ridership')
ax1.set_ylim(ymin=0)


ax1.vlines(x=11,ymin=0,ymax=max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})['Ridership']),color='r',ls='--')

plt.legend()

plt.savefig('weeklyRidership.png', bbox_inches='tight')
plt.show()

# %%
max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons'])

# %%
from datetime import datetime

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons'])
#ax1.set_title('Total Monthly Boardings, 2019-2021')
ax1.set_xlabel('Month')
ax1.set_ylabel('Boardings')

ax1.vlines(x=datetime(2020, 3, 11),ymin=0,ymax=max(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons']),color='r',ls='--')

plt.xticks(rotation=-45, ha='left')

plt.savefig('monthlyBoardingsLong.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})['Offs'])
#ax1.set_title('Total Monthly Boardings, 2019-2021')
ax1.set_xlabel('Month')
ax1.set_ylabel('Alightings')

ax1.vlines(x=datetime(2020, 3, 11),ymin=0,ymax=max(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum'})['Offs']),color='r',ls='--')

plt.xticks(rotation=-45, ha='left')

plt.savefig('monthlyAlightingsLong.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})['Ridership'])
#ax1.set_title('Total Monthly Boardings, 2019-2021')
ax1.set_xlabel('Month')
ax1.set_ylabel('Ridership')

ax1.vlines(x=datetime(2020, 3, 11),ymin=0,ymax=max(df.resample('M',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})['Ridership']),color='r',ls='--')

plt.xticks(rotation=-45, ha='left')

plt.savefig('monthlyRidershipLong.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons'][1:-1])
#ax1.set_title('Total Weekly Boardings, 2019-2021')
ax1.set_xlabel('Week')
ax1.set_ylabel('Boardings')

ax1.vlines(x=datetime(2020, 3, 11),ymin=0,ymax=max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons']),color='r',ls='--')

plt.xticks(rotation=-45, ha='left')

plt.savefig('weeklyBoardingsLong.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Offs'][1:-1])
#ax1.set_title('Total Weekly Boardings, 2019-2021')
ax1.set_xlabel('Week')
ax1.set_ylabel('Alightings')

ax1.vlines(x=datetime(2020, 3, 11),ymin=0,ymax=max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum'})['Ons']),color='r',ls='--')

plt.xticks(rotation=-45, ha='left')

plt.savefig('weeklyAlightingsLong.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.plot(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})['Ridership'][1:-1])
#ax1.set_title('Total Weekly Boardings, 2019-2021')
ax1.set_xlabel('Week')
ax1.set_ylabel('Ridership')

ax1.vlines(x=datetime(2020, 3, 11),ymin=0,ymax=max(df.resample('W',on='Date').agg({'Ons':'sum','Offs':'sum','Ridership':'sum'})['Ons']),color='r',ls='--')

plt.xticks(rotation=-45, ha='left')

plt.savefig('weeklyRidershipLong.png', bbox_inches='tight')
plt.show()

# %%
df = df.sort_values('DOW_num')
df['DOW'] = df['Date'].dt.day_name()

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

#ax1.set_title('Total Boardings 2019-2021, by Day of Week')
ax1.set_xlabel('Day')
ax1.set_ylabel('Boardings')
ax1.bar(df.groupby(['DOW_num','DOW']).sum().reset_index()['DOW'], df.groupby(['DOW_num']).sum()['Ons'])

plt.xticks(rotation=-45, ha='left')

plt.savefig('dailyBoardings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

#ax1.set_title('Total Boardings 2019-2021, by Day of Week')
ax1.set_xlabel('Day')
ax1.set_ylabel('Alightings')
ax1.bar(df.groupby(['DOW_num','DOW']).sum().reset_index()['DOW'], df.groupby(['DOW_num']).sum()['Offs'])

plt.xticks(rotation=-45, ha='left')

plt.savefig('dailyAlightings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

#ax1.set_title('Total Boardings 2019-2021, by Day of Week')
ax1.set_xlabel('Day')
ax1.set_ylabel('Ridership')
ax1.bar(df.groupby(['DOW_num','DOW']).sum().reset_index()['DOW'], df.groupby(['DOW_num']).sum()['Ridership'])

plt.xticks(rotation=-45, ha='left')

plt.savefig('dailyRidership.png', bbox_inches='tight')
plt.show()

# %%
from matplotlib.ticker import MaxNLocator

df = df.sort_values('DOW_num')

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)

#ax1.set_title('Total Boardings 2019-2021, by Hour of Day')
ax1.set_xlabel('Hour')
ax1.set_ylabel('Boardings')
ax1.bar(df.groupby(['Hour']).sum().reset_index()['Hour'][1:], df.groupby(['Hour']).sum()['Ons'][1:])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('hourlyBoardings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)

#ax1.set_title('Total Boardings 2019-2021, by Hour of Day')
ax1.set_xlabel('Hour')
ax1.set_ylabel('Alightings')
ax1.bar(df.groupby(['Hour']).sum().reset_index()['Hour'][1:], df.groupby(['Hour']).sum()['Offs'][1:])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('hourlyAlightings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)

#ax1.set_title('Total Boardings 2019-2021, by Hour of Day')
ax1.set_xlabel('Hour')
ax1.set_ylabel('Ridership')
ax1.bar(df.groupby(['Hour']).sum().reset_index()['Hour'][1:], df.groupby(['Hour']).sum()['Ridership'][1:])
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

plt.savefig('hourlyRidership.png', bbox_inches='tight')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(30, 12)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.bar(df.groupby(['stop_name']).sum().sort_values('Ons',ascending=False).reset_index()['stop_name'][0:50], df.groupby(['stop_name']).sum()['Ons'].sort_values(ascending=False)[0:50])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_xlabel('Stop')
ax1.set_ylabel('Boardings')

plt.xticks(rotation=-45, ha='left')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(7, 17)
ax1.locator_params(integer=True)
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.barh(df.groupby(['stop_name']).sum().sort_values('Ons',ascending=True).reset_index()['stop_name'][len(set(df.stop_name))-50:], df.groupby(['stop_name']).sum()['Ons'].sort_values(ascending=True)[len(set(df.stop_name))-50:])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_ylabel('Stop')
ax1.set_xlabel('Boardings')

plt.xticks(rotation=-45, ha='left')

plt.savefig('stopBoardings.png', bbox_inches='tight')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(7, 17)
ax1.locator_params(integer=True)
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.barh(df.groupby(['stop_name']).sum().sort_values('Offs',ascending=True).reset_index()['stop_name'][len(set(df.stop_name))-50:], df.groupby(['stop_name']).sum()['Offs'].sort_values(ascending=True)[len(set(df.stop_name))-50:])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_ylabel('Stop')
ax1.set_xlabel('Alightings')

plt.xticks(rotation=-45, ha='left')

plt.savefig('stopAlightings.png', bbox_inches='tight')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(7, 17)
ax1.locator_params(integer=True)
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.barh(df.groupby(['stop_name']).sum().sort_values('Ridership',ascending=True).reset_index()['stop_name'][len(set(df.stop_name))-50:], df.groupby(['stop_name']).sum()['Ridership'].sort_values(ascending=True)[len(set(df.stop_name))-50:])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_ylabel('Stop')
ax1.set_xlabel('Ridership')

plt.xticks(rotation=-45, ha='left')

plt.savefig('stopRidership.png', bbox_inches='tight')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=13) 
matplotlib.rc('ytick', labelsize=16)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(20, 12)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.bar(df.groupby(['RouteName']).sum().sort_values('Ons',ascending=False).reset_index()['RouteName'], df.groupby(['RouteName']).sum()['Ons'].sort_values(ascending=False))
#ax1.set_title('Total Boardings 2019-2021, by Route')
ax1.set_xlabel('Route')
ax1.set_ylabel('Boardings')

plt.xticks(rotation=-45, ha='left')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(6, 10)
ax1.locator_params(integer=True)
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.barh(df.groupby(['RouteName']).sum().sort_values('Ons',ascending=True).reset_index()['RouteName'][-20:], df.groupby(['RouteName']).sum()['Ons'].sort_values(ascending=True)[-20:])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_ylabel('Route')
ax1.set_xlabel('Boardings')

plt.xticks(rotation=-45, ha='left')

plt.savefig('routeBoardings.png', bbox_inches='tight')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(6, 10)
ax1.locator_params(integer=True)
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.barh(df.groupby(['RouteName']).sum().sort_values('Offs',ascending=True).reset_index()['RouteName'][-20:], df.groupby(['RouteName']).sum()['Offs'].sort_values(ascending=True)[-20:])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_ylabel('Route')
ax1.set_xlabel('Alightings')

plt.xticks(rotation=-45, ha='left')

plt.savefig('routeAlightings.png', bbox_inches='tight')
plt.show()

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=14)

fig, (ax1) = plt.subplots(1)
fig.set_size_inches(6, 10)
ax1.locator_params(integer=True)
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.barh(df.groupby(['RouteName']).sum().sort_values('Ridership',ascending=True).reset_index()['RouteName'][-20:], df.groupby(['RouteName']).sum()['Ridership'].sort_values(ascending=True)[-20:])
#ax1.set_title('Total Boardings 2019-2021, by Stop')
ax1.set_ylabel('Route')
ax1.set_xlabel('Ridership')

plt.xticks(rotation=-45, ha='left')

plt.savefig('routeRidership.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.hist(df.Ons,bins=np.arange(0,20))
ax1.set_ylabel('Boardings')

plt.xticks(rotation=-45, ha='left')

plt.savefig('histBoardings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.hist(df.Offs,bins=np.arange(0,20))
ax1.set_ylabel('Alightings')

plt.xticks(rotation=-45, ha='left')

plt.savefig('histAlightings.png', bbox_inches='tight')
plt.show()

# %%
fig, (ax1) = plt.subplots(1)
fig.set_size_inches(8, 6)
ax1.locator_params(integer=True)
ax1.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# ax1.yaxis.set_major_locator(MaxNLocator(integer=True))

ax1.hist(df.Ridership,bins=np.arange(0,20))
ax1.set_ylabel('Ridership')

plt.xticks(rotation=-45, ha='left')

plt.savefig('histRidership.png', bbox_inches='tight')
plt.show()
